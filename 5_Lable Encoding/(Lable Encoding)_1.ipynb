# %%
import pandas as pd

# %%
df = pd.DataFrame({"name" : ["Vadik","Black","Pink","Avi","Dog","Rabbit","Cat","Yash","siddharth"]})
df.head()
# Out:
#     name
# 0  Vadik
# 1  Black
# 2   Pink
# 3    Avi
# 4    Dog

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["en_data"] = le.fit_transform(df["name"])
le.fit_transform(df["name"])
# Out:
# array([6, 1, 4, 0, 3, 5, 2, 7, 8])

# %%
df
# Out:
#         name  en_data
# 0      Vadik        6
# 1      Black        1
# 2       Pink        4
# 3        Avi        0
# 4        Dog        3
# 5     Rabbit        5
# 6        Cat        2
# 7       Yash        7
# 8  siddharth        8

# %%
dataset = pd.read_csv(r"D:\Codebase\Python\Data Cleaning\Data Clening Concepts\loan_data.csv")
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0         NaN             360.0
# 1             3000                NaN        66.0             360.0
# 2             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# 2             1.0         Urban           Y

# %%
dataset["Property_Area"].unique()
# Out:
# array(['Rural', 'Urban', 'Semiurban'], dtype=object)

# %%
la = LabelEncoder()
enc_data = la.fit_transform(dataset["Property_Area"])
la.fit_transform(dataset["Property_Area"])
# Out:
# array([0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 1, 0, 1, 2, 2, 1, 2,
#        0, 1, 2, 1, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 1, 1, 1, 2, 1, 1, 0,
#        2, 2, 2, 1, 2, 2, 1, 1, 1, 1, 2, 2, 1, 1, 2, 1, 1, 1, 1, 2, 1, 1,
#        1, 1, 1, 1, 2, 2, 0, 1, 2, 1, 1, 2, 1, 1, 1, 0, 2, 1, 1, 1, 0, 2,
#        0, 1, 1, 2, 1, 0, 0, 2, 0, 1, 1, 2, 0, 0, 1, 0, 0, 1, 0, 0, 1, 2,
#        0, 1, 1, 0, 0, 0, 1, 0, 2, 1, 1, 2, 1, 1, 2, 0, 2, 1, 1, 0, 2, 1,
#        0, 1, 1, 1, 2, 1, 1, 1, 2, 1, 0, 0, 1, 2, 0, 1, 0, 2, 0, 1, 2, 2,
#        2, 1, 2, 2, 0, 0, 2, 1, 1, 0, 1, 1, 0, 2, 2, 0, 1, 1, 1, 2, 0, 1,
#        2, 2, 0, 1, 0, 1, 0, 1, 2, 2, 2, 2, 2, 2, 1, 0, 2, 0, 0, 2, 1, 1,
#        0, 0, 2, 1, 2, 1, 1, 1, 0, 0, 2, 2, 2, 1, 2, 1, 1, 0, 1, 0, 2, 0,
#        0, 1, 2, 2, 2, 1, 2, 2, 0, 0, 1, 0, 2, 2, 2, 0, 1, 2, 2, 1, 2, 2,
#        2, 1, 2, 0, 2, 1, 2, 1, 2, 2, 0, 1, 2, 0, 1, 1, 1, 2, 0, 1, 0, 2,
#        0, 1, 0, 2, 2, 2, 0, 0, 1, 0, 2, 1, 0, 1, 2, 1, 0, 1, 0, 0, 0, 0,
# ...

# %%
insert_position = 12

dataset.insert(insert_position, "Property_Area_Encoding", enc_data)

# %%
dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
# 5  LP001024   Male     Yes          2      Graduate            No
# 6  LP001027   Male     Yes          2      Graduate           NaN
# 7  LP001029   Male      No          0      Graduate            No
# 8  LP001030   Male     Yes          2      Graduate            No
# 9  LP001032   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0         NaN             360.0
# 1             3000                NaN        66.0             360.0
# ...
