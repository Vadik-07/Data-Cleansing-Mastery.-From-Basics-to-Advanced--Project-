# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"D:\Codebase\Python\Data Cleaning\Data Clening Concepts\loan_data.csv")
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0         128             360.0
# 1             3000                NaN          66             360.0
# 2             2583             2358.0         120             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# 2             1.0         Urban           Y

# %%
dataset.shape
# Out:
# (381, 13)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     1
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset.drop(columns=['Credit_History'], inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     1
# LoanAmount            0
# Loan_Amount_Term     11
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
dataset.shape
# Out:
# (337, 12)

# %%
# How much Data we Lossed in Data Cleaning
((381-337)/381)
# Out:
# 0.11548556430446194

# %%
# How much Percentage Data we Lossed in Data Cleaning
((381-337)/381)*100
# Out:
# 11.548556430446194
